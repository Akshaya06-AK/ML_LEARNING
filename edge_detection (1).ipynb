# %%
import cv2
import numpy as numpy

# %%
image=cv2.imread('/content/drive/MyDrive/akshaya /Screenshot 2026-06-02 111600 (1).png')
gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
edges=cv2.Canny(gray_image,50,150)
from google.colab.patches import cv2_imshow
cv2_imshow(image)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=RGB size=253x421>
# <PIL.Image.Image image mode=L size=253x421>

# %%
image=cv2.imread('/content/drive/MyDrive/akshaya /Screenshot 2026-06-02 115920.png')
gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
edges=cv2.Canny(gray_image,50,150)
from google.colab.patches import cv2_imshow
cv2_imshow(image)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=RGB size=462x460>
# <PIL.Image.Image image mode=L size=462x460>
