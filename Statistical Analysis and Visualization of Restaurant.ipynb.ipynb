# %%
print("data analystics")
# Out:
# data analystics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv("/content/drive/MyDrive/i1.csv")
df2=pd.read_csv("/content/drive/MyDrive/i2.csv")

# %%
df=df1.merge(df2,how='outer')

# %%
df.shape
# Out:
# (15621, 16)

# %%
df.describe()
# Out:
#         Invoice No.         Price          Qty.     Sub Total      Discount  \
# count  15621.000000  15621.000000  15621.000000  15621.000000  15621.000000
# mean   25989.963127    116.608988      1.338839    147.407080      1.262818
# std     1433.192998     63.663769      0.949814    210.127442      6.656396
# min    23465.000000     12.000000      1.000000     12.000000      0.000000
# 25%    24751.000000     50.000000      1.000000     80.000000      0.000000
# 50%    25980.000000    140.000000      1.000000    150.000000      0.000000
# 75%    27274.000000    160.000000      1.000000    170.000000      0.000000
# max    28389.000000    770.000000     28.000000  21560.000000    288.000000
#
#                 Tax   Final Total     Table No.   Covers  HSN
# count  15621.000000  15621.000000  15613.000000  15621.0  0.0
# mean       7.303668    153.447930     18.068340      0.0  NaN
# std       10.461474    219.678163     17.191377      0.0  NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15621 entries, 0 to 15620
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         15621 non-null  object
#  1   Timestamp    15621 non-null  object
#  2   Invoice No.  15621 non-null  int64
#  3   Item Name    15621 non-null  object
#  4   Price        15621 non-null  float64
#  5   Qty.         15621 non-null  float64
#  6   Sub Total    15621 non-null  float64
#  7   Discount     15621 non-null  float64
#  8   Tax          15621 non-null  float64
#  9   Final Total  15621 non-null  float64
#  10  Table No.    15613 non-null  float64
#  11  Server Name  15621 non-null  object
#  12  Covers       15621 non-null  int64
#  13  Variation    15 non-null     object
#  14  Category     15621 non-null  object
#  15  HSN          0 non-null      float64
# dtypes: float64(8), int64(2), object(6)
# memory usage: 1.9+ MB

# %%
df.head()
# Out:
#          Date            Timestamp  Invoice No.                    Item Name  \
# 0  2023-04-01  2023-04-01 13:16:03        23465          Babycorn Manchurian
# 1  2023-04-01  2023-04-01 13:16:03        23465            Chicken Kati Roll
# 2  2023-04-01  2023-04-01 13:16:03        23465         Paneer Butter Masala
# 3  2023-04-01  2023-04-01 13:16:03        23465                 Pulka (2 No)
# 4  2023-04-01  2023-04-01 13:16:03        23465  Schewan  Chicken Fried Rice
#
#    Price  Qty.  Sub Total  Discount   Tax  Final Total  Table No. Server Name  \
# 0  160.0   1.0      160.0       0.0   8.0        168.0       20.0      biller
# 1  120.0   1.0      120.0       0.0   6.0        126.0       20.0      biller
# 2  150.0   2.0      300.0       0.0  15.0        315.0       20.0      biller
# 3   40.0   3.0      120.0       0.0   6.0        126.0       20.0      biller
# 4  160.0   1.0      160.0       0.0   8.0        168.0       20.0      biller
#
# ...

# %%
df.isnull().sum()
# Out:
# Date               0
# Timestamp          0
# Invoice No.        0
# Item Name          0
# Price              0
# Qty.               0
# Sub Total          0
# Discount           0
# Tax                0
# Final Total        0
# Table No.          8
# Server Name        0
# Covers             0
# Variation      15606
# Category           0
# HSN            15621
# dtype: int64

# %%
df=df.drop(['Table No.','Server Name','Covers','Variation','HSN'],axis=1)

# %%
a=df['Final Total'].sum()
print(a)
# Out:
# 2397010.12

# %%
b=df['Invoice No.'].nunique()
print(b)
# Out:
# 4925

# %%
aov=a/b
print(aov)
# Out:
# 486.70256243654825

# %%
e=df.groupby('Item Name')['Qty.'].sum().sort_values(ascending=False)
print(e)
# Out:
# Item Name
# Mineral Water                             1672.0
# Chicken Biriyani With Raitha And Gravy    1453.0
# Butter Naan                               1046.0
# Romali Roti (1 No)                         822.0
# Lemon Soda                                 722.0
#                                            ...
# Chicken Malai Kebab                          1.0
# Soft Drinks Tin                              1.0
# Veg Pulav                                    1.0
# American Chopsey( Veg)                       1.0
# Aalu Mutter Masala                           1.0
# Name: Qty., Length: 270, dtype: float64

# %%
sns.barplot(e)
# Out:
# <Axes: xlabel='Item Name', ylabel='Qty.'>

# %%
e.plot(kind='bar')
# Out:
# <Axes: xlabel='Item Name'>

# %%
e=df.groupby('Item Name')['Qty.'].sum().sort_values(ascending=False)

# %%
top_5_items = df.groupby('Item Name')['Qty.'].sum().sort_values(ascending=False).head(5)
plt.figure(figsize=(10, 6))
plt.bar(top_5_items.index, top_5_items.values)
plt.xlabel('Item Name')
plt.ylabel('Total Quantity Sold')
plt.title('Top 5 Items by Quantity Sold')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
e=df.groupby('Item Name')['Final Total'].sum().sort_values(ascending=False)
print(e)
# Out:
# Item Name
# Chicken Biriyani With Raitha And Gravy    240730.96
# Chicken Fried Rice                        119347.20
# Butter Naan                                65387.74
# Thandoor Chicken Half                      53185.83
# Paneer Butter Masala                       49581.22
#                                             ...
# Tomato Soup                                   84.00
# Veg Kothu Parata                              73.50
# Water Bottle 500 Ml                           63.00
# Vechhu Paratha (1 No)                         52.50
# Soft Drinks Tin                               42.00
# Name: Final Total, Length: 270, dtype: float64

# %%
f=df.groupby('Timestamp')['Final Total'].sum().sort_values(ascending=False)
print(f)
# Out:
# Timestamp
# 2023-04-13 13:56:33    22638.00
# 2023-05-19 22:01:36    15123.24
# 2023-07-22 22:48:35    10702.66
# 2023-04-18 21:04:14     9598.95
# 2023-07-15 22:57:15     9159.16
#                          ...
# 2023-08-05 21:52:53       19.96
# 2023-06-06 21:52:30       19.96
# 2023-06-13 14:35:28       19.96
# 2023-07-09 22:22:28       19.96
# 2023-09-18 19:50:27       18.90
# Name: Final Total, Length: 4925, dtype: float64

# %%
df[df['Date']=='2023-09-15']['Final Total'].sum()
# Out:
# np.float64(21042.02)

# %%
f=df.groupby('Date')['Final Total'].sum().loc['2023-09-15']
print(f)
# Out:
# 21042.02

# %%
df[(df['Date']=='2023-09-15')&
(df['Item Name']=='Chicken Noodles')]['Qty.'].sum()
# Out:
# np.float64(7.0)

# %%
f=df.groupby('Invoice No.')['Final Total'].sum().sort_values(ascending=False)
print(f)
# Out:
# Invoice No.
# 23827    22638.00
# 24987    15123.24
# 26727    10702.66
# 24007     9598.95
# 26582     9159.16
#            ...
# 27070       19.96
# 25505       19.96
# 25712       19.96
# 26422       19.96
# 28342       18.90
# Name: Final Total, Length: 4925, dtype: float64

# %%
df[df['Final Total']>2000]['Invoice No.'].unique()
# Out:
# array([23827, 24987, 25427, 25434, 27210, 28126])

# %%
invoice_totals=df.groupby('Invoice No.')['Final Total'].sum()
g=invoice_totals[invoice_totals>2000]
print(g)
# Out:
# Invoice No.
# 23499     2533.64
# 23508     2011.00
# 23637     5644.82
# 23718     3517.50
# 23827    22638.00
#            ...
# 28014     3013.68
# 28126     2887.50
# 28145     4078.68
# 28259     4291.36
# 28315     2004.44
# Name: Final Total, Length: 162, dtype: float64

# %%
g=df.groupby('Invoice No.')['Final Total'].sum()
g[g>2000]
# Out:
# Invoice No.
# 23499     2533.64
# 23508     2011.00
# 23637     5644.82
# 23718     3517.50
# 23827    22638.00
#            ...
# 28014     3013.68
# 28126     2887.50
# 28145     4078.68
# 28259     4291.36
# 28315     2004.44
# Name: Final Total, Length: 162, dtype: float64

# %%
g = df.groupby('Invoice No.')['Final Total'].sum()
invoice = g[g == 2887.50]
print(invoice)
# Out:
# Invoice No.
# 28126    2887.5
# Name: Final Total, dtype: float64

# %%
df[df['Final Total']==2887.50]['Invoice No.']
# Out:
# 14772    28126
# Name: Invoice No., dtype: int64

# %%
df[df['Invoice No.']==28145][
    ['Item Name','Qty.','Final Total']]
# Out:
#                                     Item Name  Qty.  Final Total
# 14830                    Butter Chicken Gravy   1.0       160.66
# 14831                    Butter Chicken Gravy   1.0       160.66
# 14832                             Butter Naan   6.0       340.20
# 14833  Chicken Biriyani With Raitha And Gravy   2.0       302.40
# 14834                 Chicken Chettinad Gravy   2.0       321.30
# 14835              Chicken Pallipalayam Gravy   1.0       160.66
# 14836                                 Fish 65   2.0       376.12
# 14837                             Garlic Naan   6.0       340.20
# 14838                                Gobi- 65   1.0       113.40
# 14839                            Kadai Paneer   1.0       141.76
# 14840                   Kozhi Milaghuperattal   1.0       151.20
# 14841                           Mineral Water   4.0        75.60
# 14842        Pepper Tandoori Chicken ( Full )   1.0       377.06
# ...

# %%
df[df['Invoice No.']==28145][
    ['Item Name','Qty.','Final Total']].sum()
# Out:
# Item Name      Butter Chicken GravyButter Chicken GravyButter...
# Qty.                                                        40.0
# Final Total                                              4078.68
# dtype: object

# %%
from wordcloud import WordCloud
text=''.join(df['Item Name'].dropna().astype(str).values)
wordcloud=WordCloud(width=800,height=400,background_color='white').generate(text)
fig,ax=plt.subplots(figsize=(10,6))
ax.imshow(wordcloud,interpolation='bilinear')
ax.set_title('word cloud of item column')
#ax.set_xticks([])
#ax.set_yticks([])
plt.show()

# %%
from wordcloud import WordCloud
text=''.join(df['Item Name'].dropna().astype(str).values)
wordcloud=WordCloud(width=800,height=400,background_color='white').generate(text)
fig,ax=plt.subplots(figsize=(10,6))
ax.imshow(wordcloud,interpolation='bicubic')
ax.set_title('word cloud of item column')
#ax.set_xticks([])
#ax.set_yticks([])
plt.show()

# %%
from wordcloud import WordCloud
text=''.join(df['Item Name'].dropna().astype(str).values)
wordcloud=WordCloud(width=800,height=400,background_color='white').generate(text)
fig,ax=plt.subplots(figsize=(10,6))
ax.imshow(wordcloud,interpolation='nearest')
ax.set_title('word cloud of item column')
#ax.set_xticks([])
#ax.set_yticks([])
plt.show()

# %%
from wordcloud import WordCloud
text=''.join(df['Item Name'].dropna().astype(str).values)
wordcloud=WordCloud(width=800,height=400,background_color='white').generate(text)
fig,ax=plt.subplots(figsize=(10,6))
ax.imshow(wordcloud,interpolation='Antialiased')
ax.set_title('word cloud of item column')
ax.set_xticks([])
ax.set_yticks([])
plt.show()

# %%
from wordcloud import WordCloud
text=''.join(df['Item Name'].dropna().astype(str).values)
wordcloud=WordCloud(width=800,height=400,background_color='white').generate(text)
fig,ax=plt.subplots(figsize=(10,6))
ax.imshow(wordcloud,interpolation='spline36')
ax.set_title('word cloud of item column')
#ax.set_xticks([])
#ax.set_yticks([])
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/drive/MyDrive/akshaya /preprocessing_dataset.csv")
print(df)
# Out:
#       Name    Age Gender   Salary Department
# 0    Alice   25.0      F  50000.0         HR
# 1      Bob   30.0      M  60000.0    Finance
# 2  Charlie    NaN      M  55000.0         IT
# 3    David   40.0      M  58000.0         HR
# 4      Eve   22.0      F  52000.0         IT
# 5    Frank   35.0    NaN  61000.0    Finance
# 6    Grace  120.0      F      NaN    Finance
# 7    Henry   28.0      M  59000.0         HR
# 8      Ivy   29.0      F  63000.0         IT
# 9     Jack   27.0      M  62000.0    Finance

# %%
df.head()
# Out:
#       Name   Age Gender   Salary Department
# 0    Alice  25.0      F  50000.0         HR
# 1      Bob  30.0      M  60000.0    Finance
# 2  Charlie   NaN      M  55000.0         IT
# 3    David  40.0      M  58000.0         HR
# 4      Eve  22.0      F  52000.0         IT

# %%
df.tail()
# Out:
#     Name    Age Gender   Salary Department
# 5  Frank   35.0    NaN  61000.0    Finance
# 6  Grace  120.0      F      NaN    Finance
# 7  Henry   28.0      M  59000.0         HR
# 8    Ivy   29.0      F  63000.0         IT
# 9   Jack   27.0      M  62000.0    Finance

# %%
df.describe()
# Out:
#               Age        Salary
# count    9.000000      9.000000
# mean    39.555556  57777.777778
# std     30.631320   4521.553322
# min     22.000000  50000.000000
# 25%     27.000000  55000.000000
# 50%     29.000000  59000.000000
# 75%     35.000000  61000.000000
# max    120.000000  63000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        10 non-null     object
#  1   Age         9 non-null      float64
#  2   Gender      9 non-null      object
#  3   Salary      9 non-null      float64
#  4   Department  10 non-null     object
# dtypes: float64(2), object(3)
# memory usage: 532.0+ bytes

# %%
df.isnull().sum()
# Out:
# Name          0
# Age           1
# Gender        1
# Salary        1
# Department    0
# dtype: int64

# %%
# !pip install missingno
import missingno as ms
ms.bar(df)
# Out:
# ...
# <Axes: >

# %%
ms.matrix(df)
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.heatmap(df.isnull(),cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
a=10
a=a+10

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
df['Salary'].fillna(df['Salary'].median(), inplace=True)
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
df.isnull().sum()
print(df)
# Out:
#       Name         Age Gender   Salary Department
# 0    Alice   25.000000      F  50000.0         HR
# 1      Bob   30.000000      M  60000.0    Finance
# 2  Charlie   39.555556      M  55000.0         IT
# 3    David   40.000000      M  58000.0         HR
# 4      Eve   22.000000      F  52000.0         IT
# 5    Frank   35.000000      M  61000.0    Finance
# 6    Grace  120.000000      F  59000.0    Finance
# 7    Henry   28.000000      M  59000.0         HR
# 8      Ivy   29.000000      F  63000.0         IT
# 9     Jack   27.000000      M  62000.0    Finance
# /tmp/ipykernel_690/1048614220.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...
